# %% [markdown]
# ### 請寫一個函式用來計算 Mean Square Error

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

# 這邊就是將 x_lin 以及剛剛算完的 y, 當作座標值, 將101個點在平面上畫出來
# b. : b 就是 blue, 點(.) 就是最小單位的形狀, 詳細可以查 matplotlib 的官方說明
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def Mean_Square_Error(y, yp):

    mse = sum(np.square(y - yp)) / len(y)
    return mse

MSE = Mean_Square_Error(y, y_hat)
print("The Mean Square Error is %.3f" % (MSE))
# Out:
# The Mean Square Error is 249.376

# %% [markdown]
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1.你選的這組資料為何重要
#
# MNIST,為最基本手寫數字集,若要走深度學習一定要先玩過此資料集
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# MNIST（“修改後的國家標準與技術研究所”）是計算機視覺事實上的“hello world”數據集。
# 自1999年發布以來，這一經典的手寫圖像數據集已成為分類算法基準測試的基礎。
#
# 3.蒐集而來的資料型態為何
#
# 數值（像素為數值矩陣組成）
#
# 4.這組資料想解決的問題如何評估
#
# 使用卷積神經網路

# %% [markdown]
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 統計一個月的叫車地點，以區域劃分成三個等級，頻率最高的地區放置較多等候車輛，次等區域將數量減半，第三等再減半，以柏拉圖法則來規劃，先滿足首要
# 80%客戶群可以先得到最大的獲利，之後再算出多少距離的乘車距離有最大的獲利，優先安排乘車
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 2.1每次叫車的地點
# 2.2每次載客的路程距離
# 2.3載客的獲利
#
# 3.蒐集而來的資料型態為何
#
# 2.1先轉換成安放車輛的數值
# 2.2數值
# 2.3數值
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 可以先用最佳化演算法跑出放置車輛數量數，再利用多目標迴歸分析找出獲利與距離間的最大值
