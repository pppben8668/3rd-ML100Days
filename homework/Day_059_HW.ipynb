# %%
# !pip3 install --user sklearn
# !pip3 install --user --upgrade matplotlib
# Out:
# Requirement already satisfied: sklearn in /Users/shiyanchi/.local/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/shiyanchi/anaconda/lib/python3.6/site-packages (from sklearn) (0.21.3)
# Requirement already satisfied: scipy>=0.17.0 in /Users/shiyanchi/anaconda/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.3.1)
# Requirement already satisfied: numpy>=1.11.0 in /Users/shiyanchi/.local/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied: joblib>=0.11 in /Users/shiyanchi/anaconda/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.14.0)
# Requirement already up-to-date: matplotlib in /Users/shiyanchi/.local/lib/python3.6/site-packages (3.1.3)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/shiyanchi/anaconda/lib/python3.6/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /Users/shiyanchi/.local/lib/python3.6/site-packages (from matplotlib) (1.18.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/shiyanchi/anaconda/lib/python3.6/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /Users/shiyanchi/.local/lib/python3.6/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /Users/shiyanchi/.local/lib/python3.6/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/shiyanchi/.local/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib) (45.2.0)
# Requirement already satisfied, skipping upgrade: six in /Users/shiyanchi/.local/lib/python3.6/site-packages (from cycler>=0.10->matplotlib) (1.14.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)
# %matplotlib inline

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
pca = decomposition.PCA(n_components=3)

# %%
pca.fit(X)
X = pca.transform(X)

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()


for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# ### 作業
# #### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
pca = decomposition.PCA(n_components=3)

# %%
pca.fit(X)
X = pca.transform(X)

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()


for name, label in [('1', 0), ('2', 1), ('3', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
